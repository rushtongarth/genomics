# %%
import numpy as np,keras as kr,matplotlib.pyplot as plt
import sklearn.datasets as dgen

# %%
D1,L = dgen.make_blobs(centers=2,random_state=42)
x1,y1 = D1[D1[:,0]<0][:,0],D1[D1[:,0]<0][:,1]
x2,y2 = D1[D1[:,0]>0][:,0],D1[D1[:,0]>0][:,1]

plt.plot(x1,y1,'ro')
plt.plot(x2,y2,'bo')
plt.show()

# %%
raw_data = np.random.random((100,2))
#func = lambda X: 0.5*np.sin(2*np.pi*X[:,0])*np.sin(5*np.pi*X[:,1])
#data = func(raw_data)
#M,m = data.max(),data.min()
#s1 = data <= data.mean()
#s2 = data > data.mean()
x1,x2 = raw_data[:40],raw_data[40:]
y1 = 0.5*(np.cos(2*np.pi*x1)-np.sin(2*np.pi*x1))
y2 = -0.5*(np.cos(2*np.pi*x2)+np.sin(2*np.pi*x2))

# %%
#s1 = func(raw_data[:,0]) < raw_data[:,0]
#s2 = func(raw_data[:,0])>=raw_data[:,0]
#d1 = raw_data[s1]
#d2 = raw_data[s2]
f1 = lambda X: 0.5*np.sin(2*np.pi*X)*np.cos(5*np.pi*X)


#x2,y2 = d2[:,0],d2[:,1]

# %%
plt.plot(y1[:,0],y1[:,1],'bo')
plt.plot(y2[:,0],y2[:,1],'ro')
plt.plot()
plt.show()

# %%
#rng = np.arange(0,1,.01)
rng = x1
plt.plot(0.5*np.sin(2*np.pi*rng),rng,'bo')
plt.show()
